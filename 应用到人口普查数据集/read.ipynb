# %%
import pandas as pd
import numpy as np

# %%
def load_data(file_name='adult.data', condition=' >50K\n'):
    print('loading data... ' + file_name)
    file = open(file_name)
    r_X = []
    r_y = []
    for line in file.readlines():
        items = str(line).split(',')
        r_X.append(items[:-1])
        r_y.append(items[-1] == condition)
    del r_X[-1], r_y[-1]
    y = np.array(r_y).astype('int')
    X = np.array(r_X)
    X = X.T
    for i, j in zip([0, 2, 12], [10, 10000, 5]):  # 连续变量离散化
        row = X[i].astype(int)
        row = row - row % j
        X[i] = row.astype(str)
    X = X.T
    print('done!')
    print(file_name + ' size:', X.shape)
    data = _data(X, y)
    index_list = (list(range(data.x.shape[1])))
    return data, index_list
class _data(object):
    def __init__(self,x,y):
        self.x=x
        self.y=y

# %%
data,index=load_data()
# Out:
# loading data... adult.data
# done!
# adult.data size: (32561, 14)

# %%
X=pd.DataFrame(data.x)
X
# Out:
#        0                  1       2              3    4   \
# 0      30          State-gov   70000      Bachelors   13
# 1      50   Self-emp-not-inc   80000      Bachelors   13
# 2      30            Private  210000        HS-grad    9
# 3      50            Private  230000           11th    7
# 4      20            Private  330000      Bachelors   13
# 5      30            Private  280000        Masters   14
# 6      40            Private  160000            9th    5
# 7      50   Self-emp-not-inc  200000        HS-grad    9
# 8      30            Private   40000        Masters   14
# 9      40            Private  150000      Bachelors   13
# 10     30            Private  280000   Some-college   10
# 11     30          State-gov  140000      Bachelors   13
# 12     20            Private  120000      Bachelors   13
# 13     30            Private  200000     Assoc-acdm   12
# 14     40            Private  120000      Assoc-voc   11
# 15     30            Private  240000        7th-8th    4
# 16     20   Self-emp-not-inc  170000        HS-grad    9
# 17     30            Private  180000        HS-grad    9
# 18     30            Private   20000           11th    7
# 19     40   Self-emp-not-inc  290000        Masters   14
# 20     40            Private  190000      Doctorate   16
# 21     50            Private  300000        HS-grad    9
# 22     30        Federal-gov   70000            9th    5
# 23     40            Private  110000           11th    7
# 24     50            Private  100000        HS-grad    9
# 25     50          Local-gov  210000      Bachelors   13
# 26     10            Private  160000        HS-grad    9
# 27     50                  ?  180000   Some-college   10
# 28     30            Private  360000        HS-grad    9
# 29     40            Private  190000        HS-grad    9
# ...    ..                ...     ...            ...  ...
# 32531  30                  ?   30000      Bachelors   13
# 32532  30            Private  200000      Doctorate   16
# 32533  50            Private  330000      Bachelors   13
# 32534  30            Private  170000   Some-college   10
# 32535  20            Private  320000           12th    8
# 32536  30            Private  160000      Bachelors   13
# 32537  30            Private  340000        HS-grad    9
# 32538  30            Private  130000      Bachelors   13
# 32539  70                  ?  280000      Doctorate   16
# 32540  40          State-gov  250000        HS-grad    9
# 32541  40                  ?  200000        HS-grad    9
# 32542  70                  ?  120000        HS-grad    9
# 32543  40          Local-gov  110000     Assoc-acdm   12
# 32544  30            Private  190000        Masters   14
# 32545  30          Local-gov  110000     Assoc-acdm   12
# 32546  30            Private  190000     Assoc-acdm   12
# 32547  40            Private  260000        HS-grad    9
# 32548  60   Self-emp-not-inc   90000    Prof-school   15
# 32549  40          State-gov  250000   Some-college   10
# 32550  40   Self-emp-not-inc   20000   Some-college   10
# 32551  30            Private   30000           10th    6
# 32552  40            Private   80000      Assoc-voc   11
# 32553  30            Private  110000        Masters   14
# 32554  50            Private  320000        Masters   14
# 32555  20            Private  310000   Some-college   10
# 32556  20            Private  250000     Assoc-acdm   12
# 32557  40            Private  150000        HS-grad    9
# 32558  50            Private  150000        HS-grad    9
# 32559  20            Private  200000        HS-grad    9
# 32560  50       Self-emp-inc  280000        HS-grad    9
#
#                            5                   6                7   \
# 0               Never-married        Adm-clerical    Not-in-family
# 1          Married-civ-spouse     Exec-managerial          Husband
# 2                    Divorced   Handlers-cleaners    Not-in-family
# 3          Married-civ-spouse   Handlers-cleaners          Husband
# 4          Married-civ-spouse      Prof-specialty             Wife
# 5          Married-civ-spouse     Exec-managerial             Wife
# 6       Married-spouse-absent       Other-service    Not-in-family
# 7          Married-civ-spouse     Exec-managerial          Husband
# 8               Never-married      Prof-specialty    Not-in-family
# 9          Married-civ-spouse     Exec-managerial          Husband
# 10         Married-civ-spouse     Exec-managerial          Husband
# 11         Married-civ-spouse      Prof-specialty          Husband
# 12              Never-married        Adm-clerical        Own-child
# 13              Never-married               Sales    Not-in-family
# 14         Married-civ-spouse        Craft-repair          Husband
# 15         Married-civ-spouse    Transport-moving          Husband
# 16              Never-married     Farming-fishing        Own-child
# 17              Never-married   Machine-op-inspct        Unmarried
# 18         Married-civ-spouse               Sales          Husband
# 19                   Divorced     Exec-managerial        Unmarried
# 20         Married-civ-spouse      Prof-specialty          Husband
# 21                  Separated       Other-service        Unmarried
# 22         Married-civ-spouse     Farming-fishing          Husband
# 23         Married-civ-spouse    Transport-moving          Husband
# 24                   Divorced        Tech-support        Unmarried
# 25         Married-civ-spouse        Tech-support          Husband
# 26              Never-married        Craft-repair        Own-child
# 27         Married-civ-spouse                   ?          Husband
# 28                   Divorced     Exec-managerial    Not-in-family
# 29         Married-civ-spouse        Craft-repair          Husband
# ...                       ...                 ...              ...
# 32531           Never-married                   ?    Not-in-family
# 32532      Married-civ-spouse      Prof-specialty          Husband
# 32533      Married-civ-spouse     Exec-managerial          Husband
# 32534                Divorced        Adm-clerical        Unmarried
# 32535           Never-married     Protective-serv        Own-child
# 32536           Never-married     Exec-managerial    Not-in-family
# 32537           Never-married        Craft-repair    Not-in-family
# 32538                Divorced      Prof-specialty        Unmarried
# 32539      Married-civ-spouse                   ?          Husband
# 32540               Separated        Adm-clerical        Own-child
# 32541               Separated                   ?    Not-in-family
# 32542      Married-civ-spouse                   ?          Husband
# 32543                Divorced      Prof-specialty        Unmarried
# 32544                Divorced       Other-service    Not-in-family
# 32545      Married-civ-spouse        Adm-clerical             Wife
# 32546                Divorced        Tech-support    Not-in-family
# 32547      Married-civ-spouse   Machine-op-inspct          Husband
# 32548           Never-married      Prof-specialty    Not-in-family
# 32549                Divorced        Adm-clerical   Other-relative
# 32550      Married-civ-spouse        Craft-repair          Husband
# 32551      Married-civ-spouse   Handlers-cleaners          Husband
# 32552      Married-civ-spouse               Sales          Husband
# 32553           Never-married        Tech-support    Not-in-family
# 32554      Married-civ-spouse     Exec-managerial          Husband
# 32555           Never-married     Protective-serv    Not-in-family
# 32556      Married-civ-spouse        Tech-support             Wife
# 32557      Married-civ-spouse   Machine-op-inspct          Husband
# 32558                 Widowed        Adm-clerical        Unmarried
# 32559           Never-married        Adm-clerical        Own-child
# 32560      Married-civ-spouse     Exec-managerial             Wife
#
#                         8        9       10     11  12              13
# 0                    White     Male    2174      0  40   United-States
# 1                    White     Male       0      0  10   United-States
# 2                    White     Male       0      0  40   United-States
# 3                    Black     Male       0      0  40   United-States
# 4                    Black   Female       0      0  40            Cuba
# 5                    White   Female       0      0  40   United-States
# 6                    Black   Female       0      0  15         Jamaica
# 7                    White     Male       0      0  45   United-States
# 8                    White   Female   14084      0  50   United-States
# 9                    White     Male    5178      0  40   United-States
# 10                   Black     Male       0      0  80   United-States
# 11      Asian-Pac-Islander     Male       0      0  40           India
# 12                   White   Female       0      0  30   United-States
# 13                   Black     Male       0      0  50   United-States
# 14      Asian-Pac-Islander     Male       0      0  40               ?
# 15      Amer-Indian-Eskimo     Male       0      0  45          Mexico
# 16                   White     Male       0      0  35   United-States
# 17                   White     Male       0      0  40   United-States
# 18                   White     Male       0      0  50   United-States
# 19                   White   Female       0      0  45   United-States
# 20                   White     Male       0      0  60   United-States
# 21                   Black   Female       0      0  20   United-States
# 22                   Black     Male       0      0  40   United-States
# 23                   White     Male       0   2042  40   United-States
# 24                   White   Female       0      0  40   United-States
# 25                   White     Male       0      0  40   United-States
# 26                   White     Male       0      0  40   United-States
# 27      Asian-Pac-Islander     Male       0      0  60           South
# 28                   White     Male       0      0  80   United-States
# 29                   White     Male       0      0  40   United-States
# ...                    ...      ...     ...    ...  ..             ...
# 32531   Asian-Pac-Islander   Female       0      0  95   United-States
# 32532                White     Male       0      0  60   United-States
# 32533   Asian-Pac-Islander     Male       0      0  50           Japan
# 32534                White   Female       0      0  35   United-States
# 32535                Black     Male       0      0  35   United-States
# 32536                White   Female       0      0  55   United-States
# 32537                Black     Male       0      0  45   United-States
# 32538                Black   Female   15020      0  45   United-States
# 32539                White     Male       0      0  10   United-States
# 32540                White   Female       0      0  40   United-States
# 32541                Black   Female       0      0  30   United-States
# 32542                White     Male       0      0  25   United-States
# 32543                White   Female       0      0  45   United-States
# 32544                Other   Female       0      0  30   United-States
# 32545                White   Female       0      0  20   United-States
# 32546                White   Female       0      0  40   United-States
# 32547                White     Male       0      0  40          Mexico
# 32548                White     Male    1086      0  60   United-States
# 32549                White   Female       0      0  40   United-States
# 32550                White     Male       0      0  50   United-States
# 32551   Amer-Indian-Eskimo     Male       0      0  40   United-States
# 32552                White     Male       0      0  45   United-States
# 32553   Asian-Pac-Islander     Male       0      0  10          Taiwan
# 32554                White     Male       0      0  40   United-States
# 32555                White     Male       0      0  40   United-States
# 32556                White   Female       0      0  35   United-States
# 32557                White     Male       0      0  40   United-States
# 32558                White   Female       0      0  40   United-States
# 32559                White     Male       0      0  20   United-States
# 32560                White   Female   15024      0  40   United-States
#
# [32561 rows x 14 columns]

# %%
X[13]
# Out:
# 0         United-States
# 1         United-States
# 2         United-States
# 3         United-States
# 4                  Cuba
# 5         United-States
# 6               Jamaica
# 7         United-States
# 8         United-States
# 9         United-States
# 10        United-States
# 11                India
# 12        United-States
# 13        United-States
# 14                    ?
# 15               Mexico
# 16        United-States
# 17        United-States
# 18        United-States
# 19        United-States
# 20        United-States
# 21        United-States
# 22        United-States
# 23        United-States
# 24        United-States
# 25        United-States
# 26        United-States
# 27                South
# 28        United-States
# 29        United-States
#               ...
# 32531     United-States
# 32532     United-States
# 32533             Japan
# 32534     United-States
# 32535     United-States
# 32536     United-States
# 32537     United-States
# 32538     United-States
# 32539     United-States
# 32540     United-States
# 32541     United-States
# 32542     United-States
# 32543     United-States
# 32544     United-States
# 32545     United-States
# 32546     United-States
# 32547            Mexico
# 32548     United-States
# 32549     United-States
# 32550     United-States
# 32551     United-States
# 32552     United-States
# 32553            Taiwan
# 32554     United-States
# 32555     United-States
# 32556     United-States
# 32557     United-States
# 32558     United-States
# 32559     United-States
# 32560     United-States
# Name: 13, Length: 32561, dtype: object
