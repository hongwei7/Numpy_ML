# %%
import numpy as np
X=2*np.random.rand(100,1)
Y=-9*(X-0.4)**5-3*(X-1.7)**2+4+20*np.random.rand(100,1)
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot(X,Y,'.')

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features=PolynomialFeatures(degree=5,include_bias=False)
X_poly=poly_features.fit_transform(X)
from sklearn.linear_model import LinearRegression as line
clf=line()
clf.fit(X_poly,Y)
a,b=clf.intercept_,clf.coef_
a,b
# Out:
# (array([3.1077344]),
#  array([[  55.8499205 , -160.35454192,  190.77271688,  -88.45391185,
#            10.32663078]]))

# %%
plt.plot(X,Y,'.')
x=np.linspace(0,2)
y=a+b[0,1]*(x**2)+b[0,0]*x+b[0,2]*x**3+b[0,3]*x**4+b[0,4]*x**5
plt.plot(x,y)
